# %% [markdown]
# ___
# Entonces remplazando la ecuación lógistica,
#
# $$\frac{dx}{dt} = r\; x\; (1- x)$$
# por la de recurrencia se tiene:
# $ x_{n+1} = r\; x_{n}(1- x_{n})$. Donde $r$ es la razón de crecimiento máximo de la población y $x_{n}$ es la n-ésima iteración. Entonces, lo que tenemos que programar es la siguiente relación recursiva
#
# $$x_{n+1}^{(r)} = f_r(x_n^{(r)}) = rx_n^{(r)}(1-x_n^{(r)})$$

# %% [markdown]
# ** Solución a la ecuación diferencial **
#
# La ecuación diferencial inicial tiene solución analítica,
# $$ x(t) = \frac{1}{1+ (\frac{1}{x_{0}}- 1) e^{-rt}}$$

# %% [markdown]
# ### Solución numérica a la ecuación diferencial.

# %%
import numpy as np
from scipy.integrate import odeint
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
label_size = 16
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size

# %% [markdown]
# $$\frac{dx}{dt} = r\; x\; (1- x)$$

# %%
r = 1
def poblacion(x, t):
    return r * x * (1 - x)

# %%
x0 = .05
tiempo = np.linspace(0,10)
population = odeint(poblacion, x0, tiempo)

# %%
plt.plot(tiempo, population)
plt.xlabel("tiempo", fontsize = 18)
plt.ylabel("población", fontsize = 18)
plt.show()

# %% [markdown]
# ### Solución analítica

# %% [markdown]
# $$ x(t) = \frac{1}{1+ (\frac{1}{x_{0}}- 1) e^{-rt}}$$

# %%
def poblacionAna(t, x0, r):
    return 1/(1 + (1/x0 - 1)*np.exp(-r * t))

# %%
plt.plot(tiempo, poblacionAna(tiempo, x0, r))
plt.xlabel("tiempo", fontsize = 18)
plt.ylabel("población", fontsize = 18)
plt.show()

# %%
for r in np.arange(-1, 1, .1):
    plt.plot(tiempo, poblacionAna(tiempo, .5, r))
plt.xlabel("tiempo", fontsize = 18)
plt.ylabel("población", fontsize = 18)
plt.show()

# %% [markdown]
# ### Ejercicio, poner las etiquetas en la gráfica anterior.

# %% [markdown]
# ### Mapa logístico

# %% [markdown]
# $$x_{n+1}^{(r)} = f_r(x_n^{(r)}) = rx_n^{(r)}(1-x_n^{(r)})$$

# %%
def mapa_logistico(r, x):
    return r * x * (1- x)

# %%
### Mil valores para r entre .5 y 4.0
n = 1000
r = np.linspace(.5, 4, n)

# %%
iterar = 1000
ultimos = 100

# %%
# Condiciones iniciales
x = 1e-5 * np.ones(n)

# %%
plt.figure(figsize=(7, 4.5))
for i in range(iterar):
    x = mapa_logistico(r, x)
    if i >= (iterar - ultimos):
        plt.plot(r, x, ',k', alpha=.2)
plt.xlim(.4, 4)
plt.ylim(-.1, 1.1)
plt.title("Diagrama de bifurcación")
plt.xlabel('$r$', fontsize=18)
plt.ylabel('$x$', fontsize=18)
plt.show()

# %%
import datashader as ds

# %%
conda install -c bokeh datashader
