# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib as mpl
label_size = 18
mpl.rcParams['xtick.labelsize'] = label_size 
mpl.rcParams['ytick.labelsize'] = label_size 
import numpy as np

# %%
A, B = .5, .1
t = np.linspace(0,30, 100)

# %%
frecuencias = np.array([.1, .2, .5])   # Vector de diferentes frecuencias, w0
plt.figure(figsize = (7, 4))                # Ventana de gráfica con tamaño
# Graficamos para cada frecuencia
for w0 in frecuencias:
    x = A*np.cos(w0*t)+ B*np.sin(w0*t)
    plt.scatter(t, x, s = 10, lw = 0, label = "$w_0=$%s" % w0)
plt.xlabel('$t$', fontsize = 16)            # Etiqueta eje x
plt.ylabel('$x(t)$', fontsize = 16)         # Etiqueta eje y
plt.title('Oscilaciones', fontsize = 16)    # Título de la gráfica
plt.legend(bbox_to_anchor=(1.02, 0.5), prop={'size': 12})
plt.show()

# %%
from ipywidgets import *

# %%
def masa_resorte(t = 0):
    A, B, w0 = .5, .1, .5                            # Parámetros
    x = A*np.cos(w0*t)+B*np.sin(w0*t)                # Función de posición
    
    fig = plt.figure()
    ax = fig.add_subplot(1, 1, 1)
    ax.plot(x, [0],  'ko', ms = 10)
    ax.set_xlim(xmin = -0.6, xmax = .6)
    ax.axvline(x=0, color = 'r')
    ax.axhline(y=0, color = 'grey', lw = 1)
    fig.canvas.draw()

# %%
interact(masa_resorte, t = (0, 50,.01));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=50.0, step=0.01), Output()), _dom_classes=('widget-interact',))

# %%
interact_manual(masa_resorte, t = (0, 50,.01));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=50.0, step=0.01), Button(description='Run Interact', style=ButtonStyle()), Output()), _dom_classes=('widget-interact',))

# %%
def theta_t(a, b, g, l, t):
    omega_0 = np.sqrt(g/l)
    return a * np.cos(omega_0 * t) + b * np.sin(omega_0 * t)

# %%
# Hacemos un gráfico interactivo del péndulo
def pendulo_simple(t = 0):
    fig = plt.figure(figsize = (5,5))
    ax = fig.add_subplot(1, 1, 1)
    x = 2 * np.sin(theta_t(.4, .6, 9.8, 2, t))
    y =  - 2 * np.cos(theta_t(.4, .6, 9.8, 2, t))
    ax.plot(x, y, 'ko', ms = 10)
    ax.plot([0], [0], 'rD')
    ax.plot([0, x ], [0, y], 'k-', lw = 1)
    ax.set_xlim(xmin = -2.2, xmax = 2.2)
    ax.set_ylim(ymin = -2.2, ymax = .2)
    fig.canvas.draw()
    
interact(pendulo_simple, t = (0, 10,.005));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=10.0, step=0.005), Output()), _dom_classes=('widget-interact',))

# %%
# Solución: 
def theta_t(theta_0,dtheta_0,g,l,t):
    omega_0 = np.sqrt(g/l)
    return theta_0 * np.cos(omega_0 * t) + dtheta_0/omega_0 * np.sin(omega_0 * t)

# %%
def pendulo_simple(t = 0):
    fig = plt.figure(figsize = (5,5))
    ax = fig.add_subplot(1, 1, 1)
    x = 2 * np.sin(theta_t(0.1, 0, 9.8, 2, t))
    y =  - 2 * np.cos(theta_t(0.1, 0, 9.8, 2, t))
    ax.plot(x, y, 'ko', ms = 10)
    ax.plot([0], [0], 'rD')
    ax.plot([0, x ], [0, y], 'k-', lw = 1)
    ax.set_xlim(xmin = -2.2, xmax = 2.2)
    ax.set_ylim(ymin = -2.2, ymax = .2)
    fig.canvas.draw()
interact(pendulo_simple, t = (0, 10,.001));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=10.0, step=0.001), Output()), _dom_classes=('widget-interact',))

# %% [markdown]
# ### Sistema masa-resorte

# %%
k = 3  #constante elástica [N]/[m] 
m = 1 # [kg]
omega_0 = np.sqrt(k/m)
x_0 = .5  # posición inicial
dx_0 = .1 # velocidad inicial
t = np.linspace(0, 15, 300) # tiempo

x_t = x_0 *np.cos(omega_0 *t) + (dx_0/omega_0) * np.sin(omega_0 *t)        # posición
dx_t = -omega_0 * x_0 * np.sin(omega_0 * t) + dx_0 * np.cos(omega_0 * t)   # velocidad

# %%
plt.figure(figsize = (5, 5))
plt.scatter(x_t, dx_t/omega_0, cmap = 'inferno', c = dx_t, s = 8, lw = 0)
plt.xlabel('$x(t)$', fontsize = 18)
plt.ylabel('$\dot{x}(t)/\omega_0$', fontsize = 18)
plt.show()

# %% [markdown]
# #### Multiples condiciones iniciales

# %%
k = 3  #constante elástica [N]/[m] 
m = 1 # [kg]
omega_0 = np.sqrt(k/m)
t = np.linspace(0, 50, 100)

# %%
x_0s = np.array([.7, .5, .25, .1])
dx_0s = np.array([.2, .1, .05, .01])
cmaps = np.array(['viridis', 'rainbow', 'seismic', 'plasma'])

# %%
plt.figure(figsize = (6, 6))
for indx, x_0 in enumerate(x_0s):
    x_t = x_0 *np.cos(omega_0 *t) + (dx_0s[indx]/omega_0) * np.sin(omega_0 *t)
    dx_t = -omega_0 * x_0 * np.sin(omega_0 * t) + dx_0s[indx] * np.cos(omega_0 * t)
    plt.scatter(x_t,  dx_t/omega_0, cmap = cmaps[indx], 
                c = dx_t, s = 20, 
                lw = 0)
    plt.xlabel('$x(t)$', fontsize = 18)
    plt.ylabel('$\dot{x}(t)/\omega_0$', fontsize = 18)

# %% [markdown]
# ## Actividad

# %%
gravedad = np.array([274, 3.7,8.87, 9.81, 1.6, 3.7, 24.8, 10.44, 8.7, 11.15, .62])
labels = np.array(["Sol", "Mercurio", "Venus", "Tierra", "Luna", "Marte", "Jupiter", "Saturno", "Urano", "Neptuno", "Plutón"])

# %%
def theta_t(theta_0,dtheta_0,g,l,t):
    omega_0 = np.sqrt(g/l)
    return theta_0 * np.cos(omega_0 * t) + dtheta_0/omega_0 * np.sin(omega_0 * t)

# %%
theta_0 = .01
dtheta_0 = .2
l = 2
t = np.linspace(0, 100, 400)

# %%
plt.figure(figsize = (6,6))
for indx, g in enumerate(gravedad):
    x = 2 * np.sin(theta_t(theta_0, dtheta_0, g, l, t))
    omega_0 = np.sqrt(g/l)
    dtheta_t = -omega_0 * theta_0 * np.sin(omega_0 * t) + dtheta_0 * np.cos(omega_0 * t) 
    dx = 2 * np.cos(theta_t(theta_0,dtheta_0,g,l,t))*dtheta_t
    plt.scatter(x, dx/omega_0, lw = 0, s = 5, label = labels[indx])
plt.legend(bbox_to_anchor=(1.05, 0.9), prop={'size': 12})
plt.show()

# %%
plt.figure(figsize = (6,6))
for indx, g in enumerate(gravedad):
    x = 2 * np.sin(theta_t(theta_0, dtheta_0, g, l, t))
    omega_0 = np.sqrt(g/l)
    dtheta_t = -omega_0 * theta_0 * np.sin(omega_0 * t) + dtheta_0 * np.cos(omega_0 * t) 
    dx = 2 * np.cos(theta_t(theta_0,dtheta_0,g,l,t))*dtheta_t
    plt.scatter(x, dx/omega_0, lw = 0, s = 5, label = labels[indx])
#plt.legend(bbox_to_anchor=(1.05, 0.9), prop={'size': 12})
plt.xlim(xmax = .2, xmin = -.2)
plt.ylim(ymax = .2, ymin = -.2)
plt.show()

# %%
for indx, g in enumerate(gravedad):
    print(indx, g)
# Out:
# 0 274.0
# 1 3.7
# 2 8.87
# 3 9.81
# 4 1.6
# 5 3.7
# 6 24.8
# 7 10.44
# 8 8.7
# 9 11.15
# 10 0.62
