# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Definimos una función de dos variables
alpha = 0.7
phi_ext = 2 * np.pi * 0.5
def flux_qubit_potential(phi_m, phi_p):
    return 2 + alpha - 2 * np.cos(phi_p) * np.cos(phi_m) - alpha * np.cos(phi_ext - 2*phi_p)

# %%
# Definimos los rangos de las variables y mapeamos los valores a 
# una malla(para poder gráficar en 3D) de valores como sigue
phi_m = np.linspace(0, 2*np.pi, 100)
phi_p = np.linspace(0, 2*np.pi, 100)
X,Y = np.meshgrid(phi_p, phi_m)
Z = flux_qubit_potential(X, Y).T

# %%
plt.imshow(Z, cmap="viridis")
plt.colorbar();

# %%
plt.contour(Z, cmap="viridis");

# %%
from mpl_toolkits.mplot3d.axes3d import Axes3D

# %%
fig = plt.figure(figsize=(10,4))

# 
ax = fig.add_subplot(1, 2, 1, projection='3d')

p = ax.plot_surface(X, Y, Z, rstride=4, cstride=4, linewidth=0)

#
ax = fig.add_subplot(1, 2, 2, projection='3d')
p = ax.plot_surface(X, Y, Z, rstride=1, cstride=1, 
                    cmap="viridis", linewidth=0, antialiased=False)
cb = fig.colorbar(p, shrink=0.5)

# %%
fig = plt.figure(figsize=(8,6))
ax = Axes3D(fig)
ax.plot_surface(X, Y, Z, rstride = 4, cstride = 4, alpha = 0.25)
cset = ax.contour(X, Y, Z, zdir = 'z', offset = -np.pi, cmap = "inferno")
cset = ax.contour(X, Y, Z, zdir = 'x', offset = -np.pi, cmap = "inferno")
cset = ax.contour(X, Y, Z, zdir = 'y', offset = 3*np.pi, cmap = "inferno")

ax.set_xlim3d(-np.pi, 2*np.pi);
ax.set_ylim3d(0, 3*np.pi);
ax.set_zlim3d(-np.pi, 2*np.pi);

# %% [markdown]
# ### Otro ejemplo

# %%
dphi, dtheta = np.pi / 250.0, np.pi / 250.0
[phi, theta] = np.mgrid[0:np.pi + dphi * 1.5:dphi, 0:2 * np.pi +
                        dtheta * 1.5:dtheta]
m0 = 4; m1 = 3; m2 = 2; m3 = 3; m4 = 6; m5 = 2; m6 = 6; m7 = 4;

# Applying the parametric equation..
r = (np.sin(m0 * phi) ** m1 + np.cos(m2 * phi) ** m3 +
     np.sin(m4 * theta) ** m5 + np.cos(m6 * theta) ** m7)
x = r * np.sin(phi) * np.cos(theta)
y = r * np.cos(phi)
z = r * np.sin(phi) * np.sin(theta)

# %%
fig = plt.figure(figsize=(8,6))
ax = Axes3D(fig)
ax.plot_surface(x, y, z, cmap = "inferno")# rotate the axes and update
ax.view_init(15, 25)
ax.axis("off");

# %%
from matplotlib.patches import Circle, PathPatch
from mpl_toolkits.mplot3d import Axes3D
import mpl_toolkits.mplot3d.art3d as art3d

# %%
fig = plt.figure(figsize=(4,5))
ax = Axes3D(fig)
x = np.linspace(-1, 1, 100)
z = np.linspace(-2, 2, 100)
X, Z = np.meshgrid(x, z)
Y = np.sqrt(1 - X**2)

# Draw parameters
rstride = 4
cstride = 4
### Cilindro
ax.plot_surface(X, Y, Z, alpha=0.5, cmap = "viridis", rstride=rstride, cstride=cstride)
ax.plot_surface(X, -Y, Z, alpha=0.5, cmap = "viridis", rstride=rstride, cstride=cstride)
# Tapa superior e inferior
up = Circle((0, 0), 1, alpha = .5, fc = "y")
ax.add_patch(up)
art3d.pathpatch_2d_to_3d(up, z=2.1)
#inferior
down = Circle((0, 0), 1, alpha = .5, fc = "orange")
ax.add_patch(down)
art3d.pathpatch_2d_to_3d(down, z=-2.1)
#Estilo 
ax.set_xlabel("X")
ax.set_ylabel("Y")
ax.set_zlabel("Z")
ax.set_xticks([-1,1])
ax.set_yticks([-1,1])
ax.set_zticks([-2,2])
ax.set_facecolor("white")
ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.axis("on");
